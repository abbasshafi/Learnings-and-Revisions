# %%
import numpy as np
import pandas as pd

# %%
"""
Feature Extraction\ text representation/ text vectorization: 
The primary goal of feature extraction is to transform raw data into a format that is suitable for machine learning algorithms.


"""
# Out:
# '\nFeature Extraction:\n\n\n'

# %%
"""
Corupus: all the words available in a document combined is called courpus.
e.g reviews of imdb corpus would be combining all the words of the reviews together will be corpus.

Vocabulary: all the unique words from the corpus.

document: in case of imdb the individual review is called a document.




"""
# Out:
# '\nCorupus: all the words available in a document combined is called courpus.\ne.g reviews of imdb corpus would be combining all the words of the reviews together will be corpus.\n\nVocabulary: all the unique words from the corpus.\n\ndocument: in case of imdb the individual review is called a document.\n\n\n\n\n'

# %% [markdown]
# # OneHotEncoding

# %% [markdown]
# ![OneHotEncoding.png](attachment:OneHotEncoding.png)

# %%
"""
OneHotEncoding:
 
d1 People  Watch CampusX
  
d1 [[1,0,0],[0,1,0],[0,0,1]]

it creates an array for the words as above



Pros:
intutive: easily understandable
easy to implement

Cons:
Sparsity:     -reason for overfitting  -it means you have vector in which most of the values are zero so it consumes memory and resources of computer
No fixed size
OOV out of vocabulary problem
no caputring of semantic meaning
"""

# %% [markdown]
# ## Bag of Words

# %% [markdown]
# ![BoW.png](attachment:BoW.png)

# %%
df=pd.DataFrame({'text':['people watch campusx','campusx watch campusx','people write comment','campusx write comment'],
                 'output':[1,1,0,0]})
df
# Out:
#                     text  output
# 0   people watch campusx       1
# 1  campusx watch campusx       1
# 2   people write comment       0
# 3  campusx write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
bow=cv.fit_transform(df['text'])

# %%
#vocabulary
print(cv.vocabulary_)
# Out:
# {'people': 2, 'watch': 3, 'campusx': 0, 'write': 4, 'comment': 1}

# %%
print(bow[0].toarray())
print(bow[1].toarray())
# Out:
# [[1 0 1 1 0]]
# [[2 0 0 1 0]]

# %%
cv.transform(['campusx watch people write comment on campusx comment']).toarray()
# Out:
# array([[2, 2, 1, 1, 1]], dtype=int64)

# %%
"""
Adv:
simple


disAdv:
sparsity
out of vobabulary (OOV)
ordering


"""

# %%
#all the methods available on the variable
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit']

# %% [markdown]
# ## Bag of Ingrams

# %% [markdown]
# ![N-grams.png](attachment:N-grams.png)

# %%
"""
ADV:
able to capture the sematics of the sentence
easy implementation

DisAdv:
Slows down the algo
increasing n-gram increases the dimension which increases the time & computation

"""

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfv=TfidfVectorizer()

# %%
tfidf=tfv.fit_transform(df['text']).toarray()

# %%
tfidf
# Out:
# array([[0.49681612, 0.        , 0.61366674, 0.61366674, 0.        ],
#        [0.8508161 , 0.        , 0.        , 0.52546357, 0.        ],
#        [0.        , 0.57735027, 0.57735027, 0.        , 0.57735027],
#        [0.49681612, 0.61366674, 0.        , 0.        , 0.61366674]])

# %%
print(tfidf.idf_)
print(tfidf.get_feature_names_out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # print(tfidf.idf_)
# ----> 2 print(tfidf.get_feature_names_out)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_feature_names_out'
